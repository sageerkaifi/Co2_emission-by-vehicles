# %%
import numpy as np 
import pandas as pd 
import matplotlib.pyplot as plt 
import seaborn as sns
import warnings

# %%
df=pd.read_csv("CO2 Emissions_Canada.csv")
df
# Out:
#        Make        Model   Vehicle Class  Engine Size(L)  Cylinders  \
# 0     ACURA          ILX         COMPACT             2.0          4
# 1     ACURA          ILX         COMPACT             2.4          4
# 2     ACURA   ILX HYBRID         COMPACT             1.5          4
# 3     ACURA      MDX 4WD     SUV - SMALL             3.5          6
# 4     ACURA      RDX AWD     SUV - SMALL             3.5          6
# ...     ...          ...             ...             ...        ...
# 7380  VOLVO  XC40 T5 AWD     SUV - SMALL             2.0          4
# 7381  VOLVO  XC60 T5 AWD     SUV - SMALL             2.0          4
# 7382  VOLVO  XC60 T6 AWD     SUV - SMALL             2.0          4
# 7383  VOLVO  XC90 T5 AWD  SUV - STANDARD             2.0          4
# 7384  VOLVO  XC90 T6 AWD  SUV - STANDARD             2.0          4
#
#      Transmission Fuel Type  Fuel Consumption City (L/100 km)  \
# 0             AS5         Z                               9.9
# ...

# %%
df.shape
# Out:
# (7385, 12)

# %%
df.duplicated().sum()
# Out:
# 1103

# %%
df=df.drop_duplicates()

# %%
df.shape
# Out:
# (6282, 12)

# %%
df.columns
# Out:
# Index(['Make', 'Model', 'Vehicle Class', 'Engine Size(L)', 'Cylinders',
#        'Transmission', 'Fuel Type', 'Fuel Consumption City (L/100 km)',
#        'Fuel Consumption Hwy (L/100 km)', 'Fuel Consumption Comb (L/100 km)',
#        'Fuel Consumption Comb (mpg)', 'CO2 Emissions(g/km)'],
#       dtype='object')

# %%
df.columns=df.columns.str.replace(" ","_").str.lower()
df.columns
# Out:
# Index(['make', 'model', 'vehicle_class', 'engine_size(l)', 'cylinders',
#        'transmission', 'fuel_type', 'fuel_consumption_city_(l/100_km)',
#        'fuel_consumption_hwy_(l/100_km)', 'fuel_consumption_comb_(l/100_km)',
#        'fuel_consumption_comb_(mpg)', 'co2_emissions(g/km)'],
#       dtype='object')

# %%
df
# Out:
#        make        model   vehicle_class  engine_size(l)  cylinders  \
# 0     ACURA          ILX         COMPACT             2.0          4
# 1     ACURA          ILX         COMPACT             2.4          4
# 2     ACURA   ILX HYBRID         COMPACT             1.5          4
# 3     ACURA      MDX 4WD     SUV - SMALL             3.5          6
# 4     ACURA      RDX AWD     SUV - SMALL             3.5          6
# ...     ...          ...             ...             ...        ...
# 7380  VOLVO  XC40 T5 AWD     SUV - SMALL             2.0          4
# 7381  VOLVO  XC60 T5 AWD     SUV - SMALL             2.0          4
# 7382  VOLVO  XC60 T6 AWD     SUV - SMALL             2.0          4
# 7383  VOLVO  XC90 T5 AWD  SUV - STANDARD             2.0          4
# 7384  VOLVO  XC90 T6 AWD  SUV - STANDARD             2.0          4
#
#      transmission fuel_type  fuel_consumption_city_(l/100_km)  \
# 0             AS5         Z                               9.9
# ...

# %%
sns.pairplot(data=df,)

# %%
### removing the outliers
df.drop(index=[945, 946, 1431, 2544, 3616, 4509, 5575],inplace=True)
# Out:
# C:\Users\mirza\AppData\Local\Temp\ipykernel_23372\1453284096.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df.drop(index=[945, 946, 1431, 2544, 3616, 4509, 5575],inplace=True)

# %%
sns.pairplot(data=df,)

# %%
df.columns
# Out:
# Index(['make', 'model', 'vehicle_class', 'engine_size(l)', 'cylinders',
#        'transmission', 'fuel_type', 'fuel_consumption_city_(l/100_km)',
#        'fuel_consumption_hwy_(l/100_km)', 'fuel_consumption_comb_(l/100_km)',
#        'fuel_consumption_comb_(mpg)', 'co2_emissions(g/km)'],
#       dtype='object')

# %%
###preparing data for model
X=df[['engine_size(l)','cylinders','fuel_consumption_city_(l/100_km)',
       'fuel_consumption_hwy_(l/100_km)','fuel_consumption_comb_(l/100_km)']]
y=df['co2_emissions(g/km)']

# %%
print(X.shape,y.shape)
# Out:
# (6275, 5) (6275,)

# %%
## train test split
X_train,X_test,y_train,y_test=  train_test_split(X, y, test_size= 0.2, random_state= 67)

# %%
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (5020, 5)
# (5020,)
# (1255, 5)
# (1255,)

# %%
from sklearn.linear_model import LinearRegression

# %%
model=LinearRegression()

# %%
mlr=model.fit(X_train,y_train)

# %%
mlr.coef_
# Out:
# array([ 5.94449707,  6.26898003, -2.2545941 , -1.23777429, 16.8939089 ])

# %%
mlr.intercept_
# Out:
# 50.981070439886366

# %%
y_pred=model.predict(X_test)

# %%
y_pred_train=model.predict(X_train)

# %%
from sklearn.metrics import mean_squared_error,r2_score

# %%
##mse
mse=mean_squared_error(y_true=y_train,y_pred=y_pred_train)
mse
# Out:
# 418.56990097917844

# %%
test_R_squared= r2_score(y_test, y_pred)
test_R_squared
# Out:
# 0.8657457852444628

# %%
train_r2=r2_score(y_train,y_pred_train)
train_r2
# Out:
# 0.880195720428557
